# %% [markdown]
# ### **Лабораторная работа №1**
# ### Анализ сходства текстов с помощью расстояния Жаккарда
# #### *Выполнил: студент группы 8ПМ11, Кайдаров Алибек*
#
# Цель работы: разработать программу на языке программирования Python, обрабатывающую тексты и определяющая их сходство по
# расстоянию Жаккарда (Жаккара). Результаты работы оформляются в виде .ipynb файла с markdown-заметками в самом файле.
# Рекомендуется использовать платформу Anaconda 3 (Jupyter Notebook).
# Входные данные: 50 текстов объемом от 10 предложений каждое. Исходные тексты, собранные вручную,
# должны храниться в файле формата по выбору студента (.csv, .json, .xlsx и т.д.)
# Выходные данные: тепловая карта сходства (heatmap) текстов 50 на 50.

# %% [markdown]
# Импорт необходимых библиотек.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords
import nltk
import pymorphy2
import re
from time import sleep
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
# nltk.download()

# %% [markdown]
# # Не исполнять!

# %% [markdown]
# Сохранение страницы с сылками на тексты в *.html* формате.

# %%
# url = "https://ranobelib.ru/tensei-shitara-slime-datta-ken/page/8/"
# request = requests.get(url)
# source = request.text
# with open("TenSura.html", "w", encoding="utf-8") as file:
#     file.write(source)

# %% [markdown]
# Анализируя код, можно заметить, что все ссылки объеденены общим классом *ttl*.
#
# Ниже представлен цикл в ходе исполнения которого в словарь *chapters_dict* пары ключ-значение, ключом являются названия
# глав, значением ссылка на главу.

# %%
# chapters_dict = {}
# for i in range(8, 1, -1):
#     url = f"https://ranobelib.ru/tensei-shitara-slime-datta-ken/page/{i}/"
#     request = requests.get(url)
#     request.encoding = "utf-8"
#     soup = BeautifulSoup(request.text, "lxml")
#     chapters_raw = soup.find_all(class_="ttl")
#     for elem in chapters_raw:
#         chapters_dict[elem.text.replace("\t","").replace("\n","").replace("ЧИТАТЬ", "")] = elem.get("href")

# %% [markdown]
# Из словаря создан датафрейм, сохраненный в формате *.csv*.

# %%
# chapters_df = pd.DataFrame.from_dict(chapters_dict, orient="index").rename(columns={0:"href"})
# chapters_df.to_csv("TenSura_href.csv", encoding="utf-8-sig")

# %% [markdown]
# Открытие файла с ссылками и создание из него нового датафрейма содержащего 2 колонки: название главы и ссылка на неё

# %%
# hrefs_frame = pd.read_csv("TenSura_href.csv")
# hrefs_frame.columns = ["chapter_name", "href"]
# hrefs_frame = hrefs_frame.sort_values(by="chapter_name")
# hrefs_frame = hrefs_frame.set_index("chapter_name")

# %% [markdown]
# Создание цикла для обхода *hrefs_frame* и записи текста. После завершения цикла, из полученного словаря с парами
#  "название главы" - "содежимое главы" создан новый датафрейм сохраненный в формате *.csv*

# %%
# content_dict = {}
# for index, row in hrefs_frame.iterrows():
#     request = requests.get(row[0])
#     request.encoding = "utf-8"
#     soup = BeautifulSoup(request.text, "lxml")
#     content_raw = soup.find_all(class_="text")
#     content = [elem.text.replace("\n","") for elem in content_raw][0]
#     content = re.sub(r"\s+", " ", content)
#     content_dict[index] = content
#     sleep(5)
#     print(f"{index} загружена!")
# print("Все главы загружены!")

# %%
# content_df = pd.DataFrame.from_dict(content_dict, orient="index").rename(columns={0:"content"})
# content_df.to_csv("TenSura_content.csv", encoding="utf-8-sig", sep=";")

# %% [markdown]
# # Начинать исполнение здесь!

# %% [markdown]
# Из полученного файла создан датафрейм содержащий название главы и текст, готовый к дальнейшей обработке

# %%
content_frame = pd.read_csv("TenSura_content.csv", sep=";")
content_frame = content_frame.dropna(subset = ["content"], inplace=False)
content_frame.columns = ["chapter", "content"]
content_frame
# Out:
#                                                chapter  \
# 0        Глава 1. Давайте посмотрим, на что я способен
# 1                   Глава 10. Битва у деревни Гоблинов
# 2                        Глава 100. Подземный лабиринт
# 3                               Глава 101. Чёткий план
# 4                     Глава 102. Аудиенция с монстрами
# ..                                                 ...
# 305  Дополнительная история 3.2. Элегантный план по...
# 306  Дополнительная история 3.3. Элегантный план по...
# 307  Дополнительная история 4.1. Элегантный план по...
# 308  Дополнительная история 4.2. Элегантный план по...
# 309                     Пролог: Смерть… и перерождение
#
#                                                content
# 0    Темно. Темнота мешает мне разглядеть любую фор...
# 1    Клан Волчьего Клыка. Правители восточных равни...
# 2    Попрощавшись с Фьюзом, я отправился обратно в ...
# 3    Мы добрались до последнего этажа, где будет жи...
# 4    С тех пор, как я стал владыкой демонов, прошло...
# ..                                                 ...
# 305  Отказавшись от попыток избавиться от Диабло, С...
# 306  Прошло некоторое время после того, как корабль...
# 307  Остров Мальдоленд. Мое магическое восприятие у...
# 308  «Действия» и «движение» — это области, где чел...
# 309  Нормальная и никчемная жизнь. Окончил колледж,...
#
# [309 rows x 2 columns]

# %% [markdown]
# Датасет содержит 309 текстов.
# Для анализа выбрано 50 текстов с наибольшим количеством символов.
# Для отбора в датафрейме создана отдельная колонка, содержащая количество символов, по этой колонке датафрейм
# отсортирован по убыванию и выбрано 50 первых значений.

# %%
len_list = []
for index, row in content_frame.iterrows():
    len_list.append((len(content_frame["content"][index])))
content_frame["content_len"] = len_list
content_frame = content_frame.sort_values(by="content_len", ascending=False)
content_frame = content_frame.iloc[:50]

# %%
content_frame
# Out:
#                                                chapter  \
# 266              Глава 69. Рождение повелителя Демонов
# 263                        Глава 66. Случайная встреча
# 5                              Глава 103. Монстры-рабы
# 297      Глава 97. Компенсация и последующие отношения
# 98                        Глава 185. Начало новой игры
# 44                   Глава 139. Полная история встречи
# 118  Глава 198. Гобута и Карион против Веги из Четы...
# 276                             Глава 78. Демоны-лорды
# 77                 Глава 167. Точка разветвления эпохи
# 56                Глава 149. Вечер перед началом войны
# 53   Глава 146. Захват Подземного Лабиринта. Итог и...
# 281                     Глава 82. Равноправие в смерти
# 54                     Глава 147. Империя зашевелилась
# 4                     Глава 102. Аудиенция с монстрами
# 103                            Глава 189. Армия в небе
# 269            Глава 71. Единственный, кто переродился
# 272                                 Глава 74. Вельдора
# 274                Глава 76. Встреча. Принятие решений
# 116  Глава 196. Львиный Король против Веги из Четыр...
# 295                    Глава 95. Безоговорочная победа
# 72                       Глава 162. Награда и эволюция
# 71        Глава 161. Работа не бога, а Владыки Демонов
# 292               Глава 92. Священные рыцари (часть 3)
# 49                         Глава 143. Ужасающий корпус
# 7                     Глава 105. Предварительный раунд
# 101                      Глава 187. Тот, кто наблюдает
# 63      Глава 155. Первая победа и основные силы врага
# 241         Глава 46. Два договора и Основание города.
# 265                           Глава 68. Душа и надежда
# 39               Глава 134. Леон против Юуки (часть 2)
# 271                            Глава 73. Освобождённый
# 99               Глава 185.5. Отступление. Гай Кримсон
# 275                           Глава 77. Доклад Рамирис
# 6                             Глава 104. Ночь накануне
# 8                   Глава 106. Финал турнира (часть 1)
# 47                        Глава 141. Неожиданный гость
# 293               Глава 93. Священные рыцари (часть 4)
# 261      Глава 64. Последние дни в Королевской Столице
# 27                          Глава 123. Предначертанное
# 296                   Глава 96. Возможность поговорить
# 94                       Глава 181. К финальной стадии
# 96                      Глава 183. Заключение Договора
# 280                               Глава 81. На Банкете
# 117                     Глава 197. Демон против Ангела
# 283               Глава 84. Падение Королевства Фармас
# 294                                 Глава 94. Кукловод
# 66                  Глава 158. Сильнейший в Подземелье
# 86                    Глава 175. Вельдор освобождённый
# 111                     Глава 193. Всеобщая подготовка
# 260                              Глава 63. Дети и духи
#
#                                                content  content_len
# 266  После того, как разговор касательно Йому был и...        29016
# 263  После отправки Груциуса в Темпест, я попытался...        28592
# 5    Реакция тех, кто испытывает страх, может услож...        28290
# 297  Произошло много вещей, а потом всё неожиданно ...        26877
# 98   Я бросил вызов Юуки, и мы начали прикидывать с...        23072
# 44   Вчерашний кекс был восхитителен. Поэтому я ещё...        22950
# 118  — Я умру-ссу! Вот это сейчас было серьёзно опа...        22559
# 276  Демон-лорд Клэйман никогда раньше так не нервн...        22508
# 77   На лесных дорогах неподалёку от столицы Импери...        22412
# 56   Перед Императором должно было начаться Совещан...        22375
# 53   Ощутив, что в его владения вторглись захватчик...        21074
# 281  Клэйман находил ситуацию невероятной, его глаз...        20899
# 54   Дверь с громким шумом отворилась. В комнату во...        20888
# 4    С тех пор, как я стал владыкой демонов, прошло...        20879
# 103  В замке в безграничном небе, в комнате аудиенц...        20840
# 269  Они убегали со всех ног. Единственная цель, ко...        20648
# 272  Я почувствовал сильный приток энергии, когда п...        20532
# 274  На мгновение мне показалось, что всё вокруг во...        20523
# 116  Если подумать, стратегия, при которой все Влад...        20440
# 295  Мы оказались лицом друг к другу в месте, где в...        20413
# 72   Сейчас второй день с тех пор, как я оживил 700...        20372
# 71   Ощутив, как его окутывает мягкое тепло, Калгур...        19972
# 292  Ранга бежал через всё поле боя, его тело было ...        19770
# 49   Закончив предварительные наброски военных отря...        19518
# 7    После аудиенции с монстрами, живущими в Лесу Д...        19513
# 101  Из ниоткуда Дино достал двуручный меч размером...        19498
# 63   «Выложитесь на полную!» Я помню, как сказал эт...        19257
# 241  Город стал довольно красивым. «Узрите плоды мо...        18933
# 265  Прошло уже три дня. Шион так и не проснулась. ...        18910
# 39   Битва между Леоном и Юуки началась. В воздухе ...        18710
# 271  Что станет с Праздником Воскресших? Я решил, ч...        18608
# 99   Его рождение (проявление) произошло в далёком ...        18599
# 275  Неожиданно ворвалась, выкрикивая что-то… Что т...        18529
# 6    Вместе с освобождёнными эльфами редкие монстры...        18419
# 8    Прошлой ночью было выпито слишком много. Не мн...        18321
# 47   Я смотрел на катану и любовался ею. Этот меч н...        18313
# 293  Устремясь в небо, Шион начала обследовать терр...        18285
# 261  Теперь, когда о здоровье детей можно было уже ...        18273
# 27   (Фриц) По сигналу Хинаты Фриц переместился к к...        18020
# 296  Я позвал Герудо, чтобы он помог мне всё здесь ...        18008
# 94   Сидя по-турецки, Мосс занял позицию в воздухе,...        17998
# 96   Мы с Вельгринд сошлись и начали атаки, стремяс...        17770
# 280  Клэйман ликовал. Старое поколение, которое смо...        17687
# 117  Наблюдая с неба за боем между Милим и Среброво...        17563
# 283  В этот день мир снова погрузился в ужас. Возро...        17470
# 294  Сакагучи Хинате, как она думала, очень повезло...        17458
# 66   Угольно-чёрный экзоскелет с выделяющимися золо...        17377
# 86   Сейчас, как только я увидел луч надежды, ко мн...        17365
# 111  Благодаря Вальпургии я успешно заручился помощ...        17245
# 260  Мы перешли в другое место. В самую дальнюю ком...        17188

# %% [markdown]
# Преобразование датафрейма:
# - из колонки *chapter* удалены все символы, кроме номера глав
# - колонка *chapter* выбрана индексирующей;
# - из датафрейма удалена колонка *content_len*.

# %%
chapter_split = content_frame["chapter"].str.split(r" ", expand=True)
chapter_split = chapter_split[1].str.rstrip(".")
content_frame["chapter"] = chapter_split
content_frame = content_frame.set_index("chapter", drop=True).drop(["content_len"], axis=1)
content_frame
# Out:
#                                                    content
# chapter
# 69       После того, как разговор касательно Йому был и...
# 66       После отправки Груциуса в Темпест, я попытался...
# 103      Реакция тех, кто испытывает страх, может услож...
# 97       Произошло много вещей, а потом всё неожиданно ...
# 185      Я бросил вызов Юуки, и мы начали прикидывать с...
# 139      Вчерашний кекс был восхитителен. Поэтому я ещё...
# 198      — Я умру-ссу! Вот это сейчас было серьёзно опа...
# 78       Демон-лорд Клэйман никогда раньше так не нервн...
# 167      На лесных дорогах неподалёку от столицы Импери...
# 149      Перед Императором должно было начаться Совещан...
# 146      Ощутив, что в его владения вторглись захватчик...
# 82       Клэйман находил ситуацию невероятной, его глаз...
# 147      Дверь с громким шумом отворилась. В комнату во...
# 102      С тех пор, как я стал владыкой демонов, прошло...
# 189      В замке в безграничном небе, в комнате аудиенц...
# 71       Они убегали со всех ног. Единственная цель, ко...
# 74       Я почувствовал сильный приток энергии, когда п...
# 76       На мгновение мне показалось, что всё вокруг во...
# 196      Если подумать, стратегия, при которой все Влад...
# 95       Мы оказались лицом друг к другу в месте, где в...
# 162      Сейчас второй день с тех пор, как я оживил 700...
# 161      Ощутив, как его окутывает мягкое тепло, Калгур...
# 92       Ранга бежал через всё поле боя, его тело было ...
# 143      Закончив предварительные наброски военных отря...
# 105      После аудиенции с монстрами, живущими в Лесу Д...
# 187      Из ниоткуда Дино достал двуручный меч размером...
# 155      «Выложитесь на полную!» Я помню, как сказал эт...
# 46       Город стал довольно красивым. «Узрите плоды мо...
# 68       Прошло уже три дня. Шион так и не проснулась. ...
# 134      Битва между Леоном и Юуки началась. В воздухе ...
# 73       Что станет с Праздником Воскресших? Я решил, ч...
# 185.5    Его рождение (проявление) произошло в далёком ...
# 77       Неожиданно ворвалась, выкрикивая что-то… Что т...
# 104      Вместе с освобождёнными эльфами редкие монстры...
# 106      Прошлой ночью было выпито слишком много. Не мн...
# 141      Я смотрел на катану и любовался ею. Этот меч н...
# 93       Устремясь в небо, Шион начала обследовать терр...
# 64       Теперь, когда о здоровье детей можно было уже ...
# 123      (Фриц) По сигналу Хинаты Фриц переместился к к...
# 96       Я позвал Герудо, чтобы он помог мне всё здесь ...
# 181      Сидя по-турецки, Мосс занял позицию в воздухе,...
# 183      Мы с Вельгринд сошлись и начали атаки, стремяс...
# 81       Клэйман ликовал. Старое поколение, которое смо...
# 197      Наблюдая с неба за боем между Милим и Среброво...
# 84       В этот день мир снова погрузился в ужас. Возро...
# 94       Сакагучи Хинате, как она думала, очень повезло...
# 158      Угольно-чёрный экзоскелет с выделяющимися золо...
# 175      Сейчас, как только я увидел луч надежды, ко мн...
# 193      Благодаря Вальпургии я успешно заручился помощ...
# 63       Мы перешли в другое место. В самую дальнюю ком...

# %% [markdown]
# Для дальнейшего анализа каждый текст необходимо преобразовать. Для этого создана функция *clear_text()*
# Функция принимает на вход текст, в ходе исполнения происходят следующие действия:
# - все буквенные символы переводятся в строчный формат;
# - знаки пунктуации и специальные символы заменяются знаком *пробел*;
# - токенизация, в результате текст переходит в формат *list* содержащий слова;
# - лист отчищается от часто повторяющихся слов указанных в словаре библиотеки *nltk*;
# - нормализация слов с помощью функций библиотеки *pymorphy2*.
# Функция возвращает объект типа *list* содержащий слова и готовый к дальнейшему анализу.

# %%
morphy = pymorphy2.MorphAnalyzer()
stopwords_list = stopwords.words("russian")

def clear_text(text: str):
    text = text.lower()
    text = re.sub(r"[^А-Яа-я]+", " ", text)
    tokenized_text = nltk.word_tokenize(text, language="russian")
    clear_list = [word for word in tokenized_text if word not in stopwords_list]
    for i in range(len(clear_list)):
        clear_list[i] = morphy.parse(clear_list[i])[0].normal_form
    return clear_list

# %% [markdown]
# Для кажого текста в *content_frame* применена функция *clear_text()*, полученные данные занесены в новую колонку.

# %%
content_clear_list = []
for index, row in content_frame.iterrows():
    content_clear_list.append(clear_text(content_frame["content"][index]))
content_frame["content"] = content_clear_list
content_frame
# Out:
#                                                    content
# chapter
# 69       [разговор, касательно, йома, исчерпать, начать...
# 66       [отправка, груциуса, темпест, попытаться, верн...
# 103      [реакция, тот, испытывать, страх, усложнить, д...
# 97       [произойти, вещь, вс, неожиданно, перетечь, ба...
# 185      [бросить, вызов, юук, начать, прикидывать, сил...
# 139      [вчерашний, кекс, восхитительный, поэтому, ещ,...
# 198      [умереть, ссать, это, серь, зно, опасно, ясно,...
# 78       [демон, лорд, клэйман, ранний, нервничать, чел...
# 167      [лесной, дорога, неподать, ку, столица, импери...
# 149      [император, должный, начаться, совещание, ныне...
# 146      [ощутить, владение, вторгнуться, захватчик, пр...
# 82       [клэйман, находить, ситуация, невероятный, гла...
# 147      [дверь, громкий, шум, отвориться, комната, вой...
# 102      [тот, пора, стать, владыка, демон, пройти, пол...
# 189      [замок, безграничный, небо, комната, аудиенция...
# 71       [убегать, нога, единственный, цель, который, о...
# 74       [почувствовать, сильный, приток, энергия, прик...
# 76       [мгновение, показаться, вс, вокруг, взлететь, ...
# 196      [подумать, стратегия, который, владыка, демон,...
# 95       [оказаться, лицо, друг, друг, место, временной...
# 162      [второй, день, тот, пора, оживить, солдат, арм...
# 161      [ощутить, окутывать, мягкий, тепло, калгурио, ...
# 92       [ранг, бежать, вс, поле, бой, тело, такой, л, ...
# 143      [закончить, предварительный, набросок, военный...
# 105      [аудиенция, монстр, жить, лес, джура, встреча,...
# 187      [ниоткуда, дино, достать, двуручный, меч, разм...
# 155      [выложиться, полный, помнить, сказать, это, во...
# 46       [город, стать, довольно, красивый, узреть, пло...
# 68       [пройти, день, шион, проснуться, сам, дело, эт...
# 134      [битва, леон, юук, начаться, воздух, сиять, св...
# 73       [стать, праздник, воскреснуть, решить, официал...
# 185.5    [рождение, проявление, произойти, дать, кто, п...
# 77       [неожиданно, ворваться, выкрикивать, сказать, ...
# 104      [вместе, освобожд, нный, эльф, редкий, монстр,...
# 106      [прошлый, ночью, выпить, слишком, я, неважно, ...
# 141      [смотреть, катана, любоваться, она, меч, какой...
# 93       [устремиться, небо, шион, начало, обследовать,...
# 64       [здоровье, ребёнок, беспокоиться, решить, самы...
# 123      [фриц, сигнал, хината, фриц, переместиться, кр...
# 96       [позвать, герудо, помочь, вс, прибрать, способ...
# 181      [сидя, турецк, мосс, занять, позиция, воздух, ...
# 183      [вельгринд, сойтись, начать, атака, стремиться...
# 81       [клэйман, ликовать, старое, поколение, который...
# 197      [наблюдать, небо, бой, милим, среброволосый, а...
# 84       [день, мир, снова, погрузиться, ужас, возрожде...
# 94       [сакагучить, хината, думать, очень, повезти, с...
# 158      [угольный, ч, рный, экзоскелет, выделяться, зо...
# 175      [увидеть, луч, надежда, к, вернуться, спокойст...
# 193      [благодаря, вальпургия, успешно, заручиться, п...
# 63       [переслать, другой, место, самый, дальний, ком...

# %% [markdown]
# Для анализа сходства текстов реализован расчет индекса подобия Жаккарда.
# Данный метод сравнивает элементы двух наборов, чтобы увидеть, какие элементы являются общими, а какие различаются.
# Реализуется метод следующим образом:
# 1) расчет количества общих элементов выборок;
# 2) расчёт количества всех элементов выборок;
# 3) расчет отношения количества общих элементов к количеству всех элементов
# Полученное число принимает значения от 0 до 1, при этом чем ближе к 1 результат расчета, тем больше сходство текстов.
#
# $$ J=intersection(A, B) / union(A, B), $$
# где *A*, *B* соответсвующие выборки

# %%
def jac_index(a: list, b: list):
    return round((len(set(a).intersection(set(b))) / len(set(a).union(set(b)))) * 100)

# %% [markdown]
# С помощью функции *jac_index()* рассчитан индекс Жаккарда для всех кобинаций текстов

# %%
for ind, row in content_frame.iterrows():
    content_frame[ind] = [jac_index(row["content"], content_frame["content"][i]) for i in content_frame.index]
content_frame = content_frame.drop("content", axis=1)
content_frame
# Out:
#           69   66  103   97  185  139  198   78  167  149  ...  181  183   81  \
# chapter                                                    ...
# 69       100   25   19   22   20   18   18   19   19   18  ...   18   17   18
# 66        25  100   21   23   21   18   20   20   20   18  ...   18   19   19
# 103       19   21  100   21   19   21   18   19   20   21  ...   17   18   18
# 97        22   23   21  100   19   19   18   21   19   20  ...   18   18   18
# 185       20   21   19   19  100   19   21   19   23   19  ...   22   23   18
# 139       18   18   21   19   19  100   17   17   17   19  ...   16   17   17
# 198       18   20   18   18   21   17  100   18   21   18  ...   20   20   18
# 78        19   20   19   21   19   17   18  100   20   18  ...   16   17   19
# 167       19   20   20   19   23   17   21   20  100   21  ...   22   21   17
# 149       18   18   21   20   19   19   18   18   21  100  ...   18   17   18
# 146       17   16   19   18   19   18   19   18   19   19  ...   17   17   17
# 82        19   20   19   19   20   17   18   19   19   17  ...   17   18   22
# 147       18   18   22   19   20   20   17   20   20   21  ...   17   17   17
# 102       18   18   23   20   18   21   17   19   18   19  ...   16   18   18
# 189       19   20   19   19   23   19   21   20   21   19  ...   21   21   20
# 71        20   20   19   21   19   17   19   22   18   16  ...   17   18   19
# 74        19   19   17   20   19   16   19   20   19   16  ...   16   18   19
# 76        21   20   21   23   18   18   17   20   18   19  ...   15   17   18
# 196       19   18   18   18   21   16   26   18   19   20  ...   19   19   19
# 95        19   22   18   22   21   18   20   20   19   16  ...   19   20   18
# 162       18   19   20   21   19   19   20   19   19   19  ...   19   18   19
# 161       18   20   20   19   21   18   19   18   22   19  ...   20   19   19
# 92        20   21   18   20   19   16   20   20   18   17  ...   19   18   19
# 143       18   18   20   20   21   20   20   18   20   19  ...   18   19   19
# 105       17   17   21   18   17   19   17   18   16   18  ...   16   17   16
# 187       19   20   19   18   22   17   21   19   21   18  ...   20   20   19
# 155       19   20   20   20   21   19   20   19   22   22  ...   22   20   19
# 46        18   18   20   20   18   18   16   18   16   16  ...   16   16   17
# 68        23   21   19   20   18   18   17   19   18   17  ...   16   17   19
# 134       17   20   17   16   22   17   21   17   20   18  ...   20   19   19
# 73        20   20   19   22   18   18   18   20   18   18  ...   17   18   18
# 185.5     19   19   19   19   22   19   21   19   22   19  ...   21   21   20
# 77        19   20   20   20   18   18   17   20   19   18  ...   16   18   22
# 104       16   17   21   19   17   19   15   17   17   17  ...   16   15   16
# 106       17   17   17   17   17   19   19   17   17   19  ...   16   18   19
# 141       16   16   19   17   19   19   17   18   17   19  ...   16   17   17
# 93        20   22   19   22   20   17   19   21   19   16  ...   19   18   20
# 64        19   22   19   18   18   18   17   18   17   15  ...   16   17   18
# 123       18   20   17   17   21   17   19   18   19   17  ...   19   18   16
# 96        17   19   18   22   17   18   17   21   17   16  ...   15   18   18
# 181       18   18   17   18   22   16   20   16   22   18  ...  100   22   19
# 183       17   19   18   18   23   17   20   17   21   17  ...   22  100   18
# 81        18   19   18   18   18   17   18   19   17   18  ...   19   18  100
# 197       19   19   18   18   22   18   21   19   19   19  ...   20   20   20
# 84        18   17   19   19   18   17   15   17   17   19  ...   16   16   17
# 94        21   22   19   23   20   17   18   21   19   20  ...   19   19   20
# 158       18   18   18   18   20   18   19   18   20   19  ...   18   18   18
# 175       17   19   17   17   21   15   21   16   20   16  ...   19   20   18
# 193       17   17   18   19   20   16   20   16   18   20  ...   19   19   18
# 63        19   21   18   17   18   16   16   19   16   15  ...   15   17   18
#
#          197   84   94  158  175  193   63
# chapter
# 69        19   18   21   18   17   17   19
# 66        19   17   22   18   19   17   21
# 103       18   19   19   18   17   18   18
# 97        18   19   23   18   17   19   17
# 185       22   18   20   20   21   20   18
# 139       18   17   17   18   15   16   16
# 198       21   15   18   19   21   20   16
# 78        19   17   21   18   16   16   19
# 167       19   17   19   20   20   18   16
# 149       19   19   20   19   16   20   15
# 146       18   16   18   21   17   19   17
# 82        19   19   20   17   18   18   17
# 147       20   17   20   21   17   17   16
# 102       17   17   18   18   17   18   18
# 189       21   17   19   19   20   20   17
# 71        20   16   23   18   19   18   17
# 74        19   15   22   18   18   18   19
# 76        17   20   22   18   16   17   17
# 196       20   16   19   19   20   19   16
# 95        19   17   26   18   20   17   19
# 162       20   16   19   20   20   19   18
# 161       20   18   20   20   20   19   18
# 92        19   17   23   18   18   18   17
# 143       19   16   18   20   19   21   17
# 105       18   16   17   17   16   18   16
# 187       20   16   20   20   20   20   16
# 155       20   19   20   20   20   21   18
# 46        17   16   18   17   17   17   17
# 68        17   18   21   17   16   16   20
# 134       20   15   18   19   20   18   16
# 73        17   18   21   17   18   18   18
# 185.5     21   17   19   19   21   19   16
# 77        17   19   20   16   17   18   19
# 104       16   15   17   17   16   17   16
# 106       19   15   18   19   17   19   16
# 141       17   14   17   17   18   18   17
# 93        20   16   24   19   20   18   18
# 64        17   16   18   16   17   17   22
# 123       18   16   19   20   20   16   17
# 96        17   16   21   15   16   17   17
# 181       20   16   19   18   19   19   15
# 183       20   16   19   18   20   19   17
# 81        20   17   20   18   18   18   18
# 197      100   18   20   19   19   19   17
# 84        18  100   16   16   15   16   16
# 94        20   16  100   19   19   18   18
# 158       19   16   19  100   18   18   16
# 175       19   15   19   18  100   19   17
# 193       19   16   18   18   19  100   17
# 63        17   16   18   16   17   17  100
#
# [50 rows x 50 columns]

# %% [markdown]
# На основе полученной матрицы создана тепловая карта

# %%
plt.figure(figsize = (25,20))
plt.tick_params(right=True, top=True, labelright=True, labeltop=True)
plt.title("Тепловая карта сходства текстов по индексу Жаккарда")
sns.heatmap(content_frame, cmap="Set3", linewidths=.05, annot=True, fmt="3")
plt.show()
